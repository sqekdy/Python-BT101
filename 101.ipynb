# %%
# import some_pkg
# import numpy as np
# import pandas.some_lib
# from somepkg import somelib
# from somepkg import somelib as sl

# 1st rule --> Everything in python is an object.
# 2nd rule --> Duck Typing --> If it qwacks like a duck, it must be a duck.
# 3rd rule --> Can return anything (even, functions)
# 4th rule --> To view the memory location, use => id(obj)
# 5th rule-->  Identifiers are assigned to objects

                a = 5
    
        c->     (5 -> object (0X242434)
                 
                 a --6 -> object(mem)
                 
# 6th Rule-->  If you want to access the methods available within a data type(varibale) -> dir(dt)
# 7th Rule --> If you want help with certain method, do -> help(datatype.method)
# 8th Rule --> None type (Does not have any value)
                 
    
# Interviewing tips
Complexity, -> https://sqekdy.github.io/2021/03/13/Algorithmic-Complexity.html
_____________________________
For later, patterns
                 
https://nagamalliaditya3.medium.com/coding-interview-patterns-for-microsoft-facebook-google-amazon-and-netflix-83f950bac9be

# %%
# Data Structures

"""
1. List (Dynamic list. No need to manually allocate the size)
=> Properties
    Ordered (Indexed)
    Mutable (You can add, delete, or shift elements in the list.)
    Usually passed with reference (vs passed by value)
    Search time -> O(n)

=> Creation 

    mylist = [] -- Empty list
    some_other_list = [1, 2, 3, 4] -- Initialized
    alt_list = ["rabin", "2", "3", "5.6"]
    
=> Add element into list (single element)

    At the end -> mylist.append(someval)
    At arbitrary position -> mylist.insert(index, val)
    
> Add multiple elements, or another list
    mylist.extend(other_list)
    
=> Access
    Using Index ..., 0......n

2. Tuple 
=> Properties
        Immutable (Meaning, you cant change the values in a tuple once initialized
                   Helps keep data parity of returned objects from called function)
        
        Ordered (Indexe)

=> Creation
    
    mytuple = (2, 3)
    
=> Find the index
    mytuple.index(val)
    
=> Count the total values in tuple
    mytuple.count(val)
    

        
3. Set
=> Properties
        Unordered,
        Mutable,
        Cannot have duplicate elements,
        Constant access time for elements. (Everything is hashed => O(1))
        
             r   a  b   i  
        dec -12  1 |  34 13
             121 + 3413
             3534 % 100
             4
             t  y  b i
             1 21  | 34 13
             
        rabi -> tybi   
        [- , -, - , - , -]
        
        Input  ----- fn ------- index (check the value)
        

=> Initialize
    
    Empty set -> a = set() 
    Non-empty -> a= {2, 3}
    
=> Operations

    add, remove, union 2 sets, inter 2 sets, difference 2 sets
    
    
4. Dictionary

    key, value pair
    => Mutable, Unordered (starting Python 3.8, dictionaries are ordered, based on isertion order)
    => constant time access
    => since "key" is gonna be hashed,  => key cannot be mutable.
    
5. String

    => Immutable

"""

# Syntax

"""
=> Indexing
        a[0], a[1] etc
        
        
=> slicing
        a= [1, 2, 3, 4, 5]
        a[1:4] =>  a[start: end] , where start is inclusive, and end is exclusive
        works with strings as well
        
=> Iterating
        
        => Using range function
                 (start, end, step)
        
                for i in range(5):
                    Some code
                    
                for j in range(1, 6, 2)
                    1, 3, 5
                    
                for k in range (2, 4):
                    2, 3
                    
                for element in [2, 3, 4, 5]:  # For each
                    element = 2
                              3
                              4
                              5
                
                for k, v in dict.items(): {'a': 2, 'b': 3}
                    k = 
                    v = 
                    
                for keys in dict.keys():
                    
                
                

        => while => same as java 
        
        => conditional checking 
        
                if a < b:
                if b > a:
                if a == b:
                if a <= b:
                if b <= a:
                if (a and b)
                if (a or b)
                
                a = 5 = 0101
                b = 3 = 0011
                    ___________
                        0111
                
                a | b = 7
                
                a = 5 >> 1
                    0101 
                    0010   1
                    2
                    
                    5 << 1
                    0101
                0   1010 
                
                    10
                    
            
        
        

"""
